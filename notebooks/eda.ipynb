# %%
#Delay date
plt.figure(figsize=(8,5))
sns.histplot(df["delay_days"].dropna(), bins=20)
plt.title("Delay Days Distribution")
plt.show()

# %%
#Shipment Status Distribution
plt.figure(figsize=(8,5))
sns.countplot(data=df, x="shipment_status")
plt.title("Shipment Status Distribution")
plt.xticks(rotation=45)
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(12,8))

sns.heatmap(
    numeric.corr(),
    annot=True,
    cmap="Blues"
)

plt.show()

# %%
#Correlation
numeric = df.select_dtypes(include="number")

numeric.corr()
# Out:
#                      shipment_id  supplier_id  product_id  shipment_quantity  \
# shipment_id             1.000000     0.016297    0.023261          -0.002452
# supplier_id             0.016297     1.000000   -0.025479           0.016827
# product_id              0.023261    -0.025479    1.000000           0.012061
# shipment_quantity      -0.002452     0.016827    0.012061           1.000000
# unit_price              0.008293    -0.028170    0.033167           0.019059
# product_supplier_id    -0.000792    -0.004329    0.005729           0.046965
# lead_time              -0.017554     0.289517    0.013567           0.019756
# rating                 -0.024706    -0.088083   -0.001719           0.000701
# inventory_id            0.023261    -0.025479    1.000000           0.012061
# stock_quantity          0.000864    -0.002174   -0.089122          -0.006144
# disruption_id           0.012914    -0.007415    0.006470          -0.033217
# ...

# %%
df["Month"].value_counts().plot(kind="bar")

plt.title("Monthly Shipments")

plt.show()

# %%
#Monthly Shipments
df["shipment_date"] = pd.to_datetime(df["shipment_date"])

df["Month"] = df["shipment_date"].dt.month_name()

df["Month"].value_counts()
# Out:
# Month
# November     366
# January      362
# June         352
# September    352
# July         348
# March        343
# August       331
# April        327
# October      324
# May          321
# December     310
# February     297
# Name: count, dtype: int64

# %%
#Outcome Analysis
df["outcome_status"].value_counts(dropna=False)
# Out:
# outcome_status
# NaN                   3433
# Partially Resolved     154
# Pending                152
# Failed                 147
# Resolved               147
# Name: count, dtype: int64

# %%
#Severity Analysis
df["severity"].value_counts()
# Out:
# severity
# High      215
# Low       201
# Medium    184
# Name: count, dtype: int64

# %%
df["disruption_type"].dropna().value_counts().plot(kind="bar")

plt.title("Disruption Types")

plt.show()

# %%
df["disruption_type"].dropna().value_counts()
# Out:
# disruption_type
# Port Congestion     109
# Supplier Delay      108
# Machine Failure      98
# Traffic              97
# Weather              95
# Transport Strike     93
# Name: count, dtype: int64

# %%
#Disruption Analysis
df["disruption_type"].value_counts(dropna=False)
# Out:
# disruption_type
# NaN                 3433
# Port Congestion      109
# Supplier Delay       108
# Machine Failure       98
# Traffic               97
# Weather               95
# Transport Strike      93
# Name: count, dtype: int64

# %%
df.groupby("supplier_name")["lead_time"].mean()
# Out:
# supplier_name
# Bahri, Dugar and Ratti             8.09
# Balan, Virk and Mangal             3.73
# Balasubramanian, Gara and Memon    5.69
# Banerjee Group                     8.52
# Bhavsar-Sampath                    2.52
# Borah, Gill and Varma              6.15
# Chakraborty-Sengupta               5.00
# Chander-Sibal                      6.81
# Gour Ltd                           8.05
# Handa-Manda                        8.66
# Hans-Bir                           2.43
# Loyal, Varma and Tripathi          9.75
# Mitter, Srinivasan and Dixit       1.81
# Nagar, Hari and Chada              9.42
# Rajagopal-Jayaraman                1.00
# Raju and Sons                      3.81
# Sastry and Sons                    5.45
# Sule, Jaggi and Char               6.39
# Thakur and Sons                    5.83
# Wali PLC                           2.76
# Name: lead_time, dtype: float64

# %%
#Lead Time Analysis
df["lead_time"].describe()
# Out:
# count    4033.000000
# mean        5.634684
# std         2.617688
# min         1.000000
# 25%         2.760000
# 50%         5.830000
# 75%         8.090000
# max         9.750000
# Name: lead_time, dtype: float64

# %%
df["supplier_name"].value_counts().head(10).plot(kind="bar")

plt.title("Top Suppliers")

plt.show()

# %%
#Tpo Suppliers
df["supplier_name"].value_counts().head(10)
# Out:
# supplier_name
# Loyal, Varma and Tripathi       238
# Nagar, Hari and Chada           221
# Bhavsar-Sampath                 216
# Banerjee Group                  216
# Thakur and Sons                 212
# Sastry and Sons                 211
# Gour Ltd                        211
# Chakraborty-Sengupta            207
# Hans-Bir                        205
# Mitter, Srinivasan and Dixit    204
# Name: count, dtype: int64

# %%
plt.hist(df["shipment_quantity"], bins=20)

plt.title("Shipment Quantity Distribution")

plt.xlabel("Quantity")

plt.ylabel("Frequency")

plt.show()

# %%
#Shipment Quantity Analysis
df["shipment_quantity"].describe()
# Out:
# count    4033.000000
# mean      255.758244
# std       142.173803
# min        10.000000
# 25%       133.000000
# 50%       259.000000
# 75%       377.000000
# max       500.000000
# Name: shipment_quantity, dtype: float64

# %%
#Inventory Analysis
df["stock_quantity"].describe()
df.groupby("warehouse")["stock_quantity"].sum()
df.groupby("warehouse")["stock_quantity"].sum().plot(kind="bar")

plt.title("Warehouse Stock")

plt.show()
df.groupby("supplier_name")["rating"].mean().sort_values(ascending=False)
# Out:
# supplier_name
# Balasubramanian, Gara and Memon    4.88
# Bahri, Dugar and Ratti             4.85
# Handa-Manda                        4.77
# Hans-Bir                           4.68
# Loyal, Varma and Tripathi          4.64
# Nagar, Hari and Chada              4.61
# Balan, Virk and Mangal             4.49
# Wali PLC                           4.43
# Chander-Sibal                      4.37
# Sastry and Sons                    4.34
# Banerjee Group                     4.30
# Raju and Sons                      4.27
# Mitter, Srinivasan and Dixit       3.90
# Gour Ltd                           3.83
# Borah, Gill and Varma              3.78
# Bhavsar-Sampath                    3.72
# Chakraborty-Sengupta               3.56
# Sule, Jaggi and Char               3.52
# Rajagopal-Jayaraman                3.51
# Thakur and Sons                    3.50
# Name: rating, dtype: float64

# %%
#Product Category Analysis
df["category"].value_counts()
df["category"].value_counts().plot(kind="bar")

plt.title("Product Categories")

plt.show()

# %%
#Shipment Status Analysis
df["shipment_status"].value_counts()

import matplotlib.pyplot as plt

df["shipment_status"].value_counts().plot(kind="bar")

plt.title("Shipment Status")
plt.xlabel("Status")
plt.ylabel("Count")
plt.show()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum().sort_values(ascending=False)
missing = (df.isnull().sum() / len(df)) * 100
missing.sort_values(ascending=False)
# Out:
# action_taken           85.122737
# disruption_type        85.122737
# remarks                85.122737
# cost_change            85.122737
# delay_days             85.122737
# outcome_status         85.122737
# outcome_id             85.122737
# decision_date          85.122737
# disruption_id          85.122737
# recommended_action     85.122737
# decision_id            85.122737
# reported_date          85.122737
# description            85.122737
# severity               85.122737
# shipment_id             0.000000
# stock_quantity          0.000000
# last_updated            0.000000
# warehouse               0.000000
# supplier_id             0.000000
# product_name            0.000000
# product_id              0.000000
# shipment_date           0.000000
# expected_arrival        0.000000
# actual_arrival          0.000000
# shipment_quantity       0.000000
# shipment_status         0.000000
# category                0.000000
# inventory_id            0.000000
# ...

# %%
df.shape
df.head()
df.info()
df.describe(include="all")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4033 entries, 0 to 4032
# Data columns (total 35 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   shipment_id          4033 non-null   int64
#  1   supplier_id          4033 non-null   int64
#  2   product_id           4033 non-null   int64
#  3   shipment_date        4033 non-null   datetime64[ns]
#  4   expected_arrival     4033 non-null   object
#  5   actual_arrival       4033 non-null   object
#  6   shipment_quantity    4033 non-null   int64
#  7   shipment_status      4033 non-null   object
#  8   product_name         4033 non-null   object
#  9   category             4033 non-null   object
#  10  unit_price           4033 non-null   float64
#  11  product_supplier_id  4033 non-null   int64
#  12  supplier_name        4033 non-null   object
#  13  city                 4033 non-null   object
#  14  lead_time            4033 non-null   float64
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("../data/clean_supply_chain.csv")

print(df.shape)
df.head()
# Out:
# (4033, 34)
#    shipment_id  supplier_id  product_id shipment_date expected_arrival  \
# 0            1            6          29    2025-06-03       2025-06-07
# 1            2            7          84    2025-06-16       2025-06-26
# 2            3            9         119    2026-03-17       2026-03-23
# 3            4            5         140    2025-04-20       2025-04-23
# 4            5           18          56    2025-11-20       2025-11-23
#
#   actual_arrival  shipment_quantity shipment_status        product_name  \
# 0     2025-06-12                 16      In Transit  Architecto Product
# 1     2025-06-24                106         Delayed          Ab Product
# 2     2026-03-24                325      In Transit      Maxime Product
# 3     2025-04-28                419       Cancelled  Recusandae Product
# 4     2025-11-28                136         Delayed       Error Product
#
#       category  ...  reported_date  decision_id      recommended_action  \
# ...
